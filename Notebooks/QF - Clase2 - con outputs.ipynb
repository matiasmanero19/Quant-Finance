# %% [markdown]
# # Quant Finance - Clase 2

# %% [markdown]
# # Modulo yfinance para Yahoo Finance

# %% [markdown]
# Modulos necesarios
#
# Codigo.data_nyse (en github) ;
#
# pandas,
#
# matplotlib,
#
# datetime,
#
# yfinance,
#
# sys,
#
# Instalarlos con Anaconda, comando Conda o comando pip install

# %%
### Importo los modulos

import sys
sys.path.append('..')

from Codigo.data_nyse import *

import yfinance as yf
import datetime

# %% [markdown]
# ## Queremos emular lo que hicimos para BYMA

# %%
### Metodo para el web scraping
panel_yahoo_GGAL = obtener_opciones_yahoo_finance('GGAL')
panel_yahoo_GGAL
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0   GGAL200821C00005000 2020-07-21 16:48:29     5.0       6.30  7.30   7.6
# 1   GGAL200821C00007500 2020-07-22 18:19:30     7.5       4.50  4.80   5.1
# 2   GGAL200821C00010000 2020-07-28 13:43:34    10.0       2.77  2.55   2.7
# 3   GGAL200821C00012500 2020-07-28 15:05:25    12.5       0.95  0.85   1.0
# 4   GGAL200821C00015000 2020-07-28 15:05:25    15.0       0.25  0.15   0.3
# ..                  ...                 ...     ...        ...   ...   ...
# 4   GGAL220121P00012500 2020-07-23 15:03:06    12.5       4.06  3.60   4.4
# 5   GGAL220121P00015000 2020-07-10 00:16:34    15.0       7.53  5.40   6.9
# 6   GGAL220121P00017500 2020-07-10 00:16:34    17.5      10.55  7.80   9.1
# 7   GGAL220121P00020000 2020-07-23 17:15:32    20.0       9.40  8.00  10.0
# 8   GGAL220121P00022500 2020-07-23 17:14:27    22.5      11.51  9.00  13.5
#
#     change  percentChange  volume  openInterest  impliedVolatility  \
# 0     0.00       0.000000    10.0             3           1.953125
# 1     0.00       0.000000     2.0            27           1.164067
# 2    -0.23      -7.666667     3.0          1554           0.871095
# 3    -0.20     -17.391304    10.0          2648           0.753909
# 4    -0.09     -26.470589     9.0          2412           0.740237
# ..     ...            ...     ...           ...                ...
# 4     0.00       0.000000     1.0            18           0.669925
# 5     0.00       0.000000     1.0            17           0.736331
# 6     0.00       0.000000     1.0             1           0.797609
# 7     0.00       0.000000     5.0            57           0.543706
# 8     0.00       0.000000     4.0            21           0.556645
#
#     inTheMoney contractSize currency   Spot Ticker
# 0         True      REGULAR      USD  12.41   GGAL
# 1         True      REGULAR      USD  12.41   GGAL
# 2         True      REGULAR      USD  12.41   GGAL
# 3        False      REGULAR      USD  12.41   GGAL
# 4        False      REGULAR      USD  12.41   GGAL
# ..         ...          ...      ...    ...    ...
# 4         True      REGULAR      USD  12.41   GGAL
# 5         True      REGULAR      USD  12.41   GGAL
# 6         True      REGULAR      USD  12.41   GGAL
# 7         True      REGULAR      USD  12.41   GGAL
# 8         True      REGULAR      USD  12.41   GGAL
#
# [83 rows x 16 columns]

# %%
panel_ociones_GGAL_nyse_clean = obtener_panel_opciones_nyse('GGAL', True)
panel_ociones_GGAL_nyse_clean
# Out:
#                 Especie Ticker   Spot CallPut  Strike  TTM   Last  Moneyness  \
# 0   GGAL200821C00005000   GGAL  12.41       C     5.0   24   6.30   2.482000
# 44  GGAL200821P00005000   GGAL  12.41       P     5.0   24   0.05   2.482000
# 1   GGAL200821C00007500   GGAL  12.41       C     7.5   24   4.50   1.654667
# 45  GGAL200821P00007500   GGAL  12.41       P     7.5   24   0.10   1.654667
# 2   GGAL200821C00010000   GGAL  12.41       C    10.0   24   2.77   1.241000
# ..                  ...    ...    ...     ...     ...  ...    ...        ...
# 80  GGAL220121P00017500   GGAL  12.41       P    17.5  542  10.55   0.709143
# 42  GGAL220121C00020000   GGAL  12.41       C    20.0  542   1.76   0.620500
# 81  GGAL220121P00020000   GGAL  12.41       P    20.0  542   9.40   0.620500
# 43  GGAL220121C00022500   GGAL  12.41       C    22.5  542   1.51   0.551556
# 82  GGAL220121P00022500   GGAL  12.41       P    22.5  542  11.51   0.551556
#
#     impliedVolatility    Ask   Bid
# 0            1.890626   7.60  7.30
# 44           1.687502   0.05  0.00
# 1            1.125004   5.10  4.80
# 45           1.125004   0.10  0.00
# 2            0.859376   2.70  2.55
# ..                ...    ...   ...
# 80           0.798342   9.10  7.80
# 42           0.597172   2.50  0.90
# 81           0.544926  10.00  8.00
# 43           0.585698   2.15  0.45
# 82           0.558110  13.50  9.00
#
# [83 rows x 11 columns]

# %% [markdown]
# ## Modulo yfinance para Yahoo Finance

# %%
ticker = 'GGAL'
data = yf.Ticker(ticker)

#Data es un objeto
# data.info contiene informacion (mucha) del activo

data.info
# Out:
# {'zip': '1038',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 9554,
#  'longBusinessSummary': "Grupo Financiero Galicia S.A., a financial services holding company, provides various financial products and services to individuals and companies in Argentina. The company operates through Banks, Regional Credit Cards, Insurance, and Other Businesses segments. The company's products and services cover savings and current accounts, checking accounts, and credit and debit cards; personal and salary advance loans; mortgage loans; and online banking services. Its investments products and services cover fixed term, bonds and shares, FIMA funds, primary tenders, and buying and selling foreign currency; and insurance products and services cover car, home, mobile, bicycle, lifetime, protected bag, integral protection, and future fund. The company's insurance products cover options for employees, company's assets, agricultural activity, and contractual guarantees. As of December 31, 2019, it had 326 full service banking branches; 1,034 ATMs; and 1,020 self-service terminals. Grupo Financiero Galicia S.A. was founded in 1905 and is based in Buenos Aires, Argentina.",
#  'city': 'Buenos Aires',
#  'phone': '54 11 4343 7528',
#  'country': 'Argentina',
#  'companyOfficers': [],
#  'website': 'http://www.gfgsa.com',
#  'maxAge': 1,
#  'address1': 'Teniente General Juan D. Peron 430',
#  'fax': '54 11 4343 7528',
#  'industry': 'Banks—Regional',
#  'address2': '25th Floor',
#  'previousClose': 12.77,
#  'regularMarketOpen': 12.66,
#  'twoHundredDayAverage': 10.448467,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0.0913,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 12.83,
#  'navPrice': None,
#  'averageDailyVolume10Day': 1650516,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 12.77,
#  'fiftyDayAverage': 10.821143,
#  'trailingAnnualDividendRate': None,
#  'open': 12.66,
#  'toCurrency': None,
#  'averageVolume10days': 1650516,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': 1557878400,
#  'beta': 1.869899,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 12.35,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 436354,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2828663040,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 1954200,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 12.35,
#  'ask': 12.42,
#  'ytdReturn': None,
#  'askSize': 800,
#  'volume': 436354,
#  'fiftyTwoWeekHigh': 38.81,
#  'forwardPE': 2.8310502,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 5.66,
#  'bid': 12.4,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 800,
#  'dayHigh': 12.83,
#  'exchange': 'NMS',
#  'shortName': 'Grupo Financiero Galicia S.A.',
#  'longName': 'Grupo Financiero Galicia S.A.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GGAL',
#  'messageBoardId': 'finmb_1532718',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': None,
#  'profitMargins': 0.15316000000000002,
#  'enterpriseToEbitda': None,
#  '52WeekChange': -0.6603723,
#  'morningStarRiskRating': None,
#  'forwardEps': 4.38,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 142676000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': None,
#  'sharesShort': 1417757,
#  'sharesPercentSharesOut': 0.0111,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1577750400,
#  'heldPercentInstitutions': 0.26429,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.07508016,
#  'priceToBook': None,
#  'heldPercentInsiders': 0,
#  'nextFiscalYearEnd': 1640908800,
#  'mostRecentQuarter': 1585612800,
#  'shortRatio': 0.9500000000000001,
#  'sharesShortPreviousMonthDate': 1592179200,
#  'floatShares': 77086664,
#  'enterpriseValue': 1821978368,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.22,
#  'dateShortInterest': 1594771200,
#  'pegRatio': 0.06,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': 1334597,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 12.66,
#  'logo_url': 'https://logo.clearbit.com/gfgsa.com'}

# %%
# Spot price

print('Bid: ', data.info['bid'])
print('Ask: ', data.info['ask'])
print('Avg: ', (data.info['bid']+data.info['ask'])/2)
# Out:
# Bid:  12.4
# Ask:  12.42
# Avg:  12.41

# %%
# Vencimientos de opciones
vencimientos = data.options

vencimientos
# Out:
# ('2020-08-20', '2020-09-17', '2020-10-15', '2021-01-14', '2022-01-20')

# %%
# Calls y puts
calls = data.option_chain(vencimientos[0])[0]
puts = data.option_chain(vencimientos[0])[1]

puts
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0  GGAL200821P00005000 2020-07-13 13:39:01     5.0       0.05  0.00  0.05
# 1  GGAL200821P00007500 2020-07-21 13:51:52     7.5       0.10  0.00  0.10
# 2  GGAL200821P00010000 2020-07-27 18:14:15    10.0       0.15  0.10  0.25
# 3  GGAL200821P00012500 2020-07-27 18:30:55    12.5       0.85  0.85  1.05
# 4  GGAL200821P00015000 2020-07-23 16:36:10    15.0       2.56  2.70  2.90
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0     0.0            0.0     1.0           101           1.687502       False
# 1     0.0            0.0    38.0           257           1.125004       False
# 2     0.0            0.0     1.0          3717           0.787112       False
# 3     0.0            0.0   427.0          2130           0.693362        True
# 4     0.0            0.0     NaN           200           0.708987        True
#
#   contractSize currency
# 0      REGULAR      USD
# 1      REGULAR      USD
# 2      REGULAR      USD
# 3      REGULAR      USD
# 4      REGULAR      USD

# %% [markdown]
# ### Que hace internamente el metodo??

# %%
#Recorro cada vencimiento disponible y voy tomando calls por un lado y puts por otro
for vencimiento in vencimientos[1:]:
        calls = calls.append(data.option_chain(vencimiento)[0])
        puts = puts.append(data.option_chain(vencimiento)[1])

#Uno los puts y los calls
panel_opciones = calls.append(puts)

# Le agrego dos columnas utiles - Ticker y Spot

panel_opciones['Spot'] = (data.info['bid']+data.info['ask'])/2
panel_opciones['Ticker'] = ticker

panel_opciones.head(10)
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice   bid   ask  \
# 0  GGAL200821C00005000 2020-07-21 16:48:29     5.0       6.30  7.30  7.60
# 1  GGAL200821C00007500 2020-07-22 18:19:30     7.5       4.50  4.80  5.10
# 2  GGAL200821C00010000 2020-07-28 13:43:34    10.0       2.77  2.55  2.70
# 3  GGAL200821C00012500 2020-07-28 15:05:25    12.5       0.95  0.85  1.00
# 4  GGAL200821C00015000 2020-07-28 15:05:25    15.0       0.25  0.15  0.30
# 5  GGAL200821C00017500 2020-07-24 17:20:16    17.5       0.10  0.05  0.10
# 6  GGAL200821C00020000 2020-07-07 13:30:02    20.0       0.15  0.00  0.10
# 0  GGAL200918C00010000 2020-07-21 18:47:01    10.0       2.35  2.80  3.00
# 1  GGAL200918C00012500 2020-07-28 14:43:32    12.5       1.45  1.30  1.45
# 2  GGAL200918C00015000 2020-07-24 17:19:00    15.0       0.70  0.50  0.65
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0    0.00       0.000000    10.0             3           1.890626        True
# 1    0.00       0.000000     2.0            27           1.125004        True
# 2   -0.23      -7.666667     3.0          1554           0.859376        True
# 3   -0.20     -17.391304    10.0          2648           0.750003       False
# 4   -0.09     -26.470589     9.0          2412           0.738284       False
# 5    0.00       0.000000   170.0          1342           0.828127       False
# 6    0.00       0.000000     NaN             1           0.984375       False
# 0    0.00       0.000000     NaN            10           0.817385        True
# 1   -0.20     -12.121208    15.0            64           0.754885       False
# 2    0.00       0.000000     6.0             7           0.743167       False
#
#   contractSize currency   Spot Ticker
# 0      REGULAR      USD  12.41   GGAL
# 1      REGULAR      USD  12.41   GGAL
# 2      REGULAR      USD  12.41   GGAL
# 3      REGULAR      USD  12.41   GGAL
# 4      REGULAR      USD  12.41   GGAL
# 5      REGULAR      USD  12.41   GGAL
# 6      REGULAR      USD  12.41   GGAL
# 0      REGULAR      USD  12.41   GGAL
# 1      REGULAR      USD  12.41   GGAL
# 2      REGULAR      USD  12.41   GGAL

# %% [markdown]
# ## Del panel de Yahoo crudo a otro con informacion customizada (igual que antes)

# %% [markdown]
# #### *) Agrego columnas utiles

# %%
panel_opciones['Moneyness'] = 0.0
panel_opciones['TTM'] = 0
panel_opciones['CallPut'] = ''
panel_opciones = panel_opciones.reset_index()

panel_opciones.head(5)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice   bid  \
# 0      0  GGAL200821C00005000 2020-07-21 16:48:29     5.0       6.30  7.30
# 1      1  GGAL200821C00007500 2020-07-22 18:19:30     7.5       4.50  4.80
# 2      2  GGAL200821C00010000 2020-07-28 13:43:34    10.0       2.77  2.55
# 3      3  GGAL200821C00012500 2020-07-28 15:05:25    12.5       0.95  0.85
# 4      4  GGAL200821C00015000 2020-07-28 15:05:25    15.0       0.25  0.15
#
#    ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  7.6    0.00       0.000000    10.0             3           1.890626
# 1  5.1    0.00       0.000000     2.0            27           1.125004
# 2  2.7   -0.23      -7.666667     3.0          1554           0.859376
# 3  1.0   -0.20     -17.391304    10.0          2648           0.750003
# 4  0.3   -0.09     -26.470589     9.0          2412           0.738284
#
#    inTheMoney contractSize currency   Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  12.41   GGAL        0.0    0
# 1        True      REGULAR      USD  12.41   GGAL        0.0    0
# 2        True      REGULAR      USD  12.41   GGAL        0.0    0
# 3       False      REGULAR      USD  12.41   GGAL        0.0    0
# 4       False      REGULAR      USD  12.41   GGAL        0.0    0

# %% [markdown]
# #### *) Recorro las filas (1ra como ejemplo)

# %%
idx = panel_opciones.index.values[0]

# %%
callput = panel_opciones.contractSymbol.values[idx][10:11]
panel_opciones['CallPut'].values[idx] = callput

# %%
year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
month = int(panel_opciones.contractSymbol.values[idx][6:8])
day = int(panel_opciones.contractSymbol.values[idx][8:10])

hoy = datetime.date.today()
expiry_datetime = datetime.date(year, month, day)
ttm = (expiry_datetime - hoy).days

panel_opciones['TTM'].values[idx] = ttm

# %%
panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(2)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice  bid  \
# 0      0  GGAL200821C00005000 2020-07-21 16:48:29     5.0        6.3  7.3
# 1      1  GGAL200821C00007500 2020-07-22 18:19:30     7.5        4.5  4.8
#
#    ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  7.6     0.0            0.0    10.0             3           1.890626
# 1  5.1     0.0            0.0     2.0            27           1.125004
#
#    inTheMoney contractSize currency   Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  12.41   GGAL      2.482   24       C
# 1        True      REGULAR      USD  12.41   GGAL      0.000    0

# %% [markdown]
# #### *) Recorro las filas (las restantes como ejemplo)

# %%
for idx in list(panel_opciones.index.values[1:]):
        year = 2000 + int(panel_opciones.contractSymbol.values[idx][4:6])
        month = int(panel_opciones.contractSymbol.values[idx][6:8])
        day = int(panel_opciones.contractSymbol.values[idx][8:10])
        callput = panel_opciones.contractSymbol.values[idx][10:11]

        hoy = datetime.date.today()
        expiry_datetime = datetime.date(year, month, day)
        ttm = (expiry_datetime - hoy).days

        panel_opciones['TTM'].values[idx] = ttm
        panel_opciones['CallPut'].values[idx] = callput
        panel_opciones['Moneyness'].values[idx] = panel_opciones['Spot'].values[idx] / panel_opciones['strike'].values[idx]

# %%
panel_opciones.head(10)
# Out:
#    index       contractSymbol       lastTradeDate  strike  lastPrice   bid  \
# 0      0  GGAL200821C00005000 2020-07-21 16:48:29     5.0       6.30  7.30
# 1      1  GGAL200821C00007500 2020-07-22 18:19:30     7.5       4.50  4.80
# 2      2  GGAL200821C00010000 2020-07-28 13:43:34    10.0       2.77  2.55
# 3      3  GGAL200821C00012500 2020-07-28 15:05:25    12.5       0.95  0.85
# 4      4  GGAL200821C00015000 2020-07-28 15:05:25    15.0       0.25  0.15
# 5      5  GGAL200821C00017500 2020-07-24 17:20:16    17.5       0.10  0.05
# 6      6  GGAL200821C00020000 2020-07-07 13:30:02    20.0       0.15  0.00
# 7      0  GGAL200918C00010000 2020-07-21 18:47:01    10.0       2.35  2.80
# 8      1  GGAL200918C00012500 2020-07-28 14:43:32    12.5       1.45  1.30
# 9      2  GGAL200918C00015000 2020-07-24 17:19:00    15.0       0.70  0.50
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  7.60    0.00       0.000000    10.0             3           1.890626
# 1  5.10    0.00       0.000000     2.0            27           1.125004
# 2  2.70   -0.23      -7.666667     3.0          1554           0.859376
# 3  1.00   -0.20     -17.391304    10.0          2648           0.750003
# 4  0.30   -0.09     -26.470589     9.0          2412           0.738284
# 5  0.10    0.00       0.000000   170.0          1342           0.828127
# 6  0.10    0.00       0.000000     NaN             1           0.984375
# 7  3.00    0.00       0.000000     NaN            10           0.817385
# 8  1.45   -0.20     -12.121208    15.0            64           0.754885
# 9  0.65    0.00       0.000000     6.0             7           0.743167
#
#    inTheMoney contractSize currency   Spot Ticker  Moneyness  TTM CallPut
# 0        True      REGULAR      USD  12.41   GGAL   2.482000   24       C
# 1        True      REGULAR      USD  12.41   GGAL   1.654667   24       C
# 2        True      REGULAR      USD  12.41   GGAL   1.241000   24       C
# 3       False      REGULAR      USD  12.41   GGAL   0.992800   24       C
# 4       False      REGULAR      USD  12.41   GGAL   0.827333   24       C
# 5       False      REGULAR      USD  12.41   GGAL   0.709143   24       C
# 6       False      REGULAR      USD  12.41   GGAL   0.620500   24       C
# 7        True      REGULAR      USD  12.41   GGAL   1.241000   52       C
# 8       False      REGULAR      USD  12.41   GGAL   0.992800   52       C
# 9       False      REGULAR      USD  12.41   GGAL   0.827333   52       C

# %% [markdown]
# #### Panel Limpio

# %%
panel_opciones = panel_opciones.rename(
            columns={'lastTradeDate': 'Last_Date', 'contractSymbol': 'Especie', 'strike': 'Strike', 'bid': 'Bid',
                     'ask': 'Ask', 'lastPrice': 'Last'}, inplace=False)

panel_opciones = panel_opciones.sort_values(['TTM', 'Ticker', 'Strike', 'CallPut'])

panel_opciones = panel_opciones[['Especie', 'Ticker', 'Spot', 'CallPut', 'Strike', 'TTM', 'Last', 'Moneyness']]

# %%
panel_opciones
# Out:
#                 Especie Ticker   Spot CallPut  Strike  TTM   Last  Moneyness
# 0   GGAL200821C00005000   GGAL  12.41       C     5.0   24   6.30   2.482000
# 44  GGAL200821P00005000   GGAL  12.41       P     5.0   24   0.05   2.482000
# 1   GGAL200821C00007500   GGAL  12.41       C     7.5   24   4.50   1.654667
# 45  GGAL200821P00007500   GGAL  12.41       P     7.5   24   0.10   1.654667
# 2   GGAL200821C00010000   GGAL  12.41       C    10.0   24   2.77   1.241000
# ..                  ...    ...    ...     ...     ...  ...    ...        ...
# 80  GGAL220121P00017500   GGAL  12.41       P    17.5  542  10.55   0.709143
# 42  GGAL220121C00020000   GGAL  12.41       C    20.0  542   1.76   0.620500
# 81  GGAL220121P00020000   GGAL  12.41       P    20.0  542   9.40   0.620500
# 43  GGAL220121C00022500   GGAL  12.41       C    22.5  542   1.51   0.551556
# 82  GGAL220121P00022500   GGAL  12.41       P    22.5  542  11.51   0.551556
#
# [83 rows x 8 columns]

# %% [markdown]
# ## Ploteando los datos

# %% [markdown]
# ### Para cada vencimiento, grafico los strikes

# %%
# NYSE
panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)

TTMs = list(set(panel_opciones_ggal_nyse_limpio.TTM.values))
TTMs
# Out:
# [171, 80, 52, 24, 542]

# %%
TTM = 29
panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == 29) & (panel_opciones_ggal_nyse_limpio.CallPut == "C")].head(10)
# Out:
# Empty DataFrame
# Columns: [Especie, Ticker, Spot, CallPut, Strike, TTM, Last, Moneyness, impliedVolatility, Ask, Bid]
# Index: []

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
CP = "P"
for TTM in TTMs:
    Ks = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.TTM == TTM) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios,'*', label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %% [markdown]
# ### Para cada strike, grafico los TTM

# %%
Ks = list(set(panel_opciones_ggal_nyse_limpio.Strike.values))

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks:
    TTMs = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_ggal_nyse_limpio[(panel_opciones_ggal_nyse_limpio.Strike == K) & (panel_opciones_ggal_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Ploteando los datos con un ticker mega liquido

# %%
# NYSE AAPL
ticker = 'AAPL'
panel_opciones_nyse_limpio = obtener_panel_opciones_nyse(ticker, True)

TTMs = list(set(panel_opciones_nyse_limpio.TTM.values))
TTMs.sort()
TTMs
# Out:
# [3, 10, 17, 24, 31, 38, 52, 80, 115, 143, 171, 325, 416, 542, 689, 780]

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[0:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[5:11]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[11:17]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[0:5]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[5:11]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for TTM in TTMs[11:17]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    plt.plot(Ks, precios, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al Strike')
    
plt.show()

# %%
Ks = list(set(panel_opciones_nyse_limpio.Strike.values))
Ks.sort()
len(Ks)
# Out:
# 122

# %%
from matplotlib import pyplot as plt
CP = "C"
for K in Ks[45:55]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al TTM')
    
plt.show()

# %%
from matplotlib import pyplot as plt
CP = "P"
for K in Ks[100:]:
    TTMs = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.Strike == K) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    if len(TTMs)>1:
        plt.plot(TTMs, precios,'*', label='Strike = '+str(K))

plt.legend()

plt.xlabel('TTM')
plt.ylabel('Precio de mercado del Put')
plt.title('Precio de mercado de las opciones Put con respecto al TTM')
    
plt.show()

# %% [markdown]
# ## Pasar a Excel

# %%
panel_opciones_ggal_nyse_crudo = obtener_panel_opciones_nyse('GGAL', False)
panel_opciones_ggal_nyse_crudo.to_excel('Clase_2_panel_opciones_ggal_nyse_crudo.xls')

panel_opciones_ggal_nyse_limpio = obtener_panel_opciones_nyse('GGAL', True)
panel_opciones_ggal_nyse_limpio.to_excel('Clase_2_panel_opciones_ggal_nyse_limpio.xls')


panel_opciones_aapl_nyse_limpio = obtener_panel_opciones_nyse('AAPL', True)
panel_opciones_aapl_nyse_limpio.to_excel('Clase_2_panel_opciones_aapl_nyse_limpio.xls')

# %% [markdown]
# ## Extras vistas en clase

# %%
TTMs = list(set(panel_opciones_nyse_limpio.TTM.values))
TTMs.sort()

# %% [markdown]
# ### Plot de Volatilidades Implicitas dadas por Yahoo Finances

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[0:3]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    iv = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].impliedVolatility.values
    plt.plot(Ks, iv, '.',label='TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('IV')
plt.title('IV de yahoo de las opciones Call con respecto al strike')
    
plt.show()

# %% [markdown]
# ### Usar en vez de LAST, (BID+ASK) /2

# %%
panel_opciones_nyse_limpio['Avg']=(panel_opciones_nyse_limpio.Bid+panel_opciones_nyse_limpio.Ask)/2

# %%
from matplotlib import pyplot as plt
CP = "C"
for TTM in TTMs[14:15]:
    Ks = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Strike.values
    precios_L = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Last.values
    precios_A = panel_opciones_nyse_limpio[(panel_opciones_nyse_limpio.TTM == TTM) & (panel_opciones_nyse_limpio.CallPut == CP)].Avg.values
    plt.plot(Ks, precios_L, '.',label='LAST TTM = '+str(TTM))
    plt.plot(Ks, precios_A, '*',label='AVG TTM = '+str(TTM))


plt.legend()

plt.xlabel('Strike')
plt.ylabel('Precio de mercado del Call')
plt.title('Precio de mercado de las opciones Call con respecto al Strike')
    
plt.show()
